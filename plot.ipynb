# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sample_results.csv')

# %%
df = df.sort_values(by=['date'])

# %%
df.plot(x='date', y=['temperature', 'crimes'], figsize=(10,5), grid=True)

# %%
df.plot(x='date', y=['crimes'], figsize=(10,5), grid=True)

# %%
df.plot(x='date', y=['temperature'], figsize=(10,5), grid=True)
